# %%
import requests
import os

def download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template, realization_digit):
    # Ensure the directory exists
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Loop through each frequency and realization
    for realization in realizations:
        for frequency in frequencies: 
            realization_str = str(realization).zfill(realization_digit)
            filename = filename_template.format(frequency=frequency, realization=realization_str)
            file_path = os.path.join(directory, filename)

            # Check if the file already exists
            if os.path.exists(file_path):
                print(f"File {filename} already exists. Skipping download.")
                continue

            # Format the URL with the current frequency and realization
            url = url_template.format(frequency=frequency, realization=realization_str)

            # Send a GET request to the URL
            response = requests.get(url)

            # Check if the request was successful
            if response.status_code == 200:
                # Open the file in binary write mode and write the content
                with open(file_path, 'wb') as f:
                    f.write(response.content)
                print(f"Downloaded {file_path}")
            else:
                print(f"Failed to download data for frequency {frequency} and realization {realization_str}. Status code: {response.status_code}")

# Example usage
directory = 'CMB_realizations'
# frequencies = ["030", "044", "070", "100", "143", "217", "353", "545", "857"]  # Example frequencies
# frequencies = [ "545", "857"]  # Example frequencies
frequencies = ["030", "044", "070", "100", "143", "217", "353"]  # Example frequencies

realizations = range(30)  # Example: 10 realizations from 0 to 9
url_template = "http://pla.esac.esa.int/pla/aio/product-action?SIMULATED_MAP.FILE_ID=febecop_ffp10_lensed_scl_cmb_{frequency}_mc_{realization}.fits"
filename_template = "febecop_ffp10_lensed_scl_cmb_{frequency}_mc_{realization}.fits"
realization_digit = 4 
download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template, realization_digit)
# Out:
# File febecop_ffp10_lensed_scl_cmb_030_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0000.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0001.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0002.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0003.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0004.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0005.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0006.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0007.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0008.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_030_mc_0009.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_044_mc_0009.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_070_mc_0009.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_100_mc_0009.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_143_mc_0009.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_217_mc_0009.fits already exists. Skipping download.
# File febecop_ffp10_lensed_scl_cmb_353_mc_0009.fits already exists. Skipping download.
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_030_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_044_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_070_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_100_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_143_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_217_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_353_mc_0010.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_030_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_044_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_070_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_100_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_143_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_217_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_353_mc_0011.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_030_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_044_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_070_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_100_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_143_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_217_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_353_mc_0012.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_030_mc_0013.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_044_mc_0013.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_070_mc_0013.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_100_mc_0013.fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3092282/1969279508.py in <module>
#      44 filename_template = "febecop_ffp10_lensed_scl_cmb_{frequency}_mc_{realization}.fits"
#      45 realization_digit = 4
# ---> 46 download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template, realization_digit)
#
# /tmp/ipykernel_3092282/1969279508.py in download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template, realization_digit)
#      23
#      24             # Send a GET request to the URL
# ---> 25             response = requests.get(url)
#      26
#      27             # Check if the request was successful
#
# ~/.local/lib/python3.10/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/.local/lib/python3.10/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/.local/lib/python3.10/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# ~/.local/lib/python3.10/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# ~/.local/lib/python3.10/site-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# ~/.local/lib/python3.10/site-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# ~/.local/lib/python3.10/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     622         """
#     623         if self.chunked and self.supports_chunked_reads():
# --> 624             for line in self.read_chunked(amt, decode_content=decode_content):
#     625                 yield line
#     626         else:
#
# ~/.local/lib/python3.10/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     829                 if self.chunk_left == 0:
#     830                     break
# --> 831                 chunk = self._handle_chunk(amt)
#     832                 decoded = self._decode(
#     833                     chunk, decode_content=decode_content, flush_decoder=False
#
# ~/.local/lib/python3.10/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     782             returned_chunk = value
#     783         else:  # amt > self.chunk_left
# --> 784             returned_chunk = self._fp._safe_read(self.chunk_left)
#     785             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     786             self.chunk_left = None
#
# /usr/lib/python3.10/http/client.py in _safe_read(self, amt)
#     629         IncompleteRead exception can be used to detect the problem.
#     630         """
# --> 631         data = self.fp.read(amt)
#     632         if len(data) < amt:
#     633             raise IncompleteRead(data, amt-len(data))
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Different path, for simplied processing (the downloaded fits files are name as febecop, symbeam is the original code)

frequencies = [ "545", "857"]  # Example frequencies
filename_template = "febecop_ffp10_lensed_scl_cmb_{frequency}_mc_{realization}.fits"
url_template = "http://pla.esac.esa.int/pla/aio/product-action?SIMULATED_MAP.FILE_ID=symbeam_ffp10_lensed_scl_cmb_{frequency}_mc_{realization}.fits"

download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template, 4)
# Out:
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0000.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0000.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0001.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0001.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0002.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0002.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0003.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0003.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0004.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0004.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0005.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0005.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0006.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0006.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0007.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0007.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0008.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0008.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_545_mc_0009.fits
# Downloaded CMB_realizations/febecop_ffp10_lensed_scl_cmb_857_mc_0009.fits

# %%
# synchrotron 040??? 
frequencies = ["030", "040", "070", "100", "143", "217", "353", "545", "857"]  # Example frequencies
realizations = range(1)  
filename_template = "COM_SimMap_clusterirps-ffp10-skyinbands-{frequency}_2048_R3.00_full.fits"
url_template = "http://pla.esac.esa.int/pla/aio/product-action?SIMULATED_MAP.FILE_ID=COM_SimMap_clusterirps-ffp10-skyinbands-{frequency}_2048_R3.00_full.fits"

download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template)

# COM_SimMap_clusterirps-ffp10-skyinbands-030_2048_R3.00_full.fits
# Out:
# File COM_SimMap_clusterirps-ffp10-skyinbands-030_2048_R3.00_full.fits already exists. Skipping download.
# Downloaded CMB_realizations/COM_SimMap_clusterirps-ffp10-skyinbands-040_2048_R3.00_full.fits
# File COM_SimMap_clusterirps-ffp10-skyinbands-070_2048_R3.00_full.fits already exists. Skipping download.
# File COM_SimMap_clusterirps-ffp10-skyinbands-100_2048_R3.00_full.fits already exists. Skipping download.
# File COM_SimMap_clusterirps-ffp10-skyinbands-143_2048_R3.00_full.fits already exists. Skipping download.
# File COM_SimMap_clusterirps-ffp10-skyinbands-217_2048_R3.00_full.fits already exists. Skipping download.
# File COM_SimMap_clusterirps-ffp10-skyinbands-353_2048_R3.00_full.fits already exists. Skipping download.
# File COM_SimMap_clusterirps-ffp10-skyinbands-545_2048_R3.00_full.fits already exists. Skipping download.
# File COM_SimMap_clusterirps-ffp10-skyinbands-857_2048_R3.00_full.fits already exists. Skipping download.

# %%
# synchrotron
frequencies = ["030", "044", "070", "100", "143", "217", "353", "545", "857"]  # Example frequencies
realizations = range(1)  
filename_template = "COM_SimMap_synchrotron-ffp10-skyinbands-{frequency}_2048_R3.00_full.fits"
url_template = "http://pla.esac.esa.int/pla/aio/product-action?SIMULATED_MAP.FILE_ID=COM_SimMap_synchrotron-ffp10-skyinbands-{frequency}_2048_R3.00_full.fits"

download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template)
# Out:
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-030_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-044_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-070_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-100_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-143_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-217_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-353_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-545_2048_R3.00_full.fits
# Downloaded CMB_realizations/COM_SimMap_synchrotron-ffp10-skyinbands-857_2048_R3.00_full.fits

# %%
# Noise
frequencies = ["030", "044", "070", "100", "143", "217", "353", "545", "857"]  # Example frequencies
realizations = range(10)  
realization_digit = 5
filename_template = "ffp10_noise_{frequency}_full_map_mc_{realization}.fits"
url_template = "http://pla.esac.esa.int/pla/aio/product-action?SIMULATED_MAP.FILE_ID=ffp10_noise_{frequency}_full_map_mc_{realization}.fits"

download_cmb_realizations(directory, frequencies, realizations, url_template, filename_template,realization_digit)
# Out:
# File ffp10_noise_030_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_044_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_070_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_100_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_143_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_217_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_353_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_545_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_857_full_map_mc_00000.fits already exists. Skipping download.
# File ffp10_noise_030_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_044_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_070_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_100_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_143_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_217_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_353_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_545_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_857_full_map_mc_00001.fits already exists. Skipping download.
# File ffp10_noise_030_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_044_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_070_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_100_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_143_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_217_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_353_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_545_full_map_mc_00002.fits already exists. Skipping download.
# File ffp10_noise_857_full_map_mc_00002.fits already exists. Skipping download.
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00003.fits
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00004.fits
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00005.fits
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00006.fits
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00007.fits
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00008.fits
# Downloaded CMB_realizations/ffp10_noise_030_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_044_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_070_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_100_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_143_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_217_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_353_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_545_full_map_mc_00009.fits
# Downloaded CMB_realizations/ffp10_noise_857_full_map_mc_00009.fits
