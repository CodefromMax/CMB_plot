# %%
pip install s2fft
# Out:
# ...
#   Using cached s2fft-1.1.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached jax-0.4.28-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached jaxlib-0.4.28-cp311-cp311-macosx_10_14_x86_64.whl.metadata (1.8 kB)
# ...
#   Using cached torch-2.2.2-cp311-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# ...
#   Using cached pyssht-1.5.2.tar.gz (99 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached ducc0-0.34.0-cp311-cp311-macosx_10_14_x86_64.whl.metadata (28 kB)
# ...
#   Using cached ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# ...
