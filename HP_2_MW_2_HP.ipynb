# %%
import skyclean

from skyclean import CMB_data

# %%
import jax
jax.config.update("jax_enable_x64", True)
import s2fft
import healpy as hp
import numpy as np
import s2wav
import s2wav.filters as filters
import matplotlib.pyplot as plt
# %matplotlib inline 


# Step 1: Read the Healpix map
CMB_map_path = 'data/planck_simulation/ffp10_newdust_total_030_full_map.fits'
original_healpix_map = hp.read_map(CMB_map_path)

# %%
CMB_data_30 = skyclean.CMB_data.CMB_Data(CMB_map_path)
# Out:
# hello from CMB_Data

# %%
CMB_data_30.plot_mollview(CMB_data.original_hp_map, title='Original Map')

# %%
CMB_data_30.original_hp_alm = hp.map2alm(CMB_data_30.original_hp_map, lmax=CMB_data_30.lmax)

CMB_data_30.original_mw_alm = CMB_data.hp_alm_to_mw_alm(CMB_data_30.original_hp_alm, lmax=CMB_data_30.lmax)

# %%
frequency = "30"
hp.mollview(
        original_healpix_map*1e6,
        coord=["G"],
        title="Full Sky CMB at "+frequency,
        unit=r"$\mu$K",
        min=-300, 
        max=300,
    )

# %%
# ##################################################################
# print("nside:", nside)
# print(f"Shape of alm: {alm.shape}")

# # the total number of spherical harmonic coefficients (alm)
# # n_coeff = （L_max+1）*（L_max+2）/2
# n_coeff = ((L_max-1)+1)*(((L_max-1))+2)//2
# n_coeff_verify = hp.Alm.getsize(L_max-1)
# print(f"Total number of coefficients (n_coeff): {n_coeff}, (n_coeff_verify): {n_coeff_verify}")
# Out:
# nside: 1024
# Shape of alm: (2098176,)
# Total number of coefficients (n_coeff): 2098176, (n_coeff_verify): 2098176

# %%
# Step 2: Convert Healpix map to spherical harmonic coefficients
# convention: L_max = nside * 2
nside = hp.get_nside(original_healpix_map)
L_max = nside*2  # Define maximum multipole moment / detail level
alm = hp.map2alm(original_healpix_map, lmax=L_max-1)
# lmax = L_max - 1 because python is 0-indexed

# %%
# Step 3: Rearrange coefficients for s2wav: from 1 dimensional to 2 dimensional
# s2fft only works with alm in 2d
alm_2d = np.zeros((L_max, 2 * L_max - 1), dtype=np.complex128)

for l in range(L_max):
    for m in range(-l, l + 1):
        index = hp.Alm.getidx(L_max - 1, l, abs(m))
        if m < 0:
            alm_2d[l, L_max + m - 1] = (-1)**m * np.conj(alm[index])
        else:
            alm_2d[l, L_max + m - 1] = alm[index]
print(f"Shape of alm_2d: {alm_2d.shape}")
# Out:
# Shape of alm_2d: (2048, 4095)

# %%
# Step 4: Apply s2fft to the 2d alm to get the map in MW sampling (2d)
# original_MW_Map = s2fft.inverse(alm_2d, L_max)
# np.save('data/original_MW_map.npy', original_MW_Map)
stored_original_MW_map = np.load('data/original_MW_map.npy')

# %%
# Step 5: Apply s2wav to the MW map to get the wavelet and scaling coefficients
N_directions = 1  # Number of directional wavelets
filter = filters.filters_directional_vectorised(L_max, N_directions)

wavelet_coeffs, scaling_coeffs = s2wav.analysis(stored_original_MW_map, L_max, N_directions, filters=filter,reality = False)

# Convert each element in f_wav to a numpy array and save it
for i, wav in enumerate(wavelet_coeffs):
    np_wav = np.array(wav)  # Convert JAX array to numpy array
    np.save(f"convolution/wavelet_coefficient/wav_30_{i}", np_wav)  

# Convert  f_scal to a numpy array and save it
np_scal = np.array(scaling_coeffs)  # Convert JAX array to numpy array
np.save(f"convolution/scaling_coefficient/scal_30", np_scal)  
stored_wavelet_coeffs = [np.load(f"convolution/wavelet_coefficient/wav_30_{i}.npy", allow_pickle=True) for i in range(12)]
stored_scaling_coeffs = np.load("convolution/scaling_coefficient/scal_30.npy")

# %%
for i in range(len(stored_wavelet_coeffs)):
    print(f"Shape of wavelet_coeffs:{i} {stored_wavelet_coeffs[i].shape}")
# print(f"Shape of wavelet_coeffs: {stored_wavelet_coeffs[1].shape}")
# Out:
# Shape of wavelet_coeffs:0 (1, 4, 7)
# Shape of wavelet_coeffs:1 (1, 4, 7)
# Shape of wavelet_coeffs:2 (1, 8, 15)
# Shape of wavelet_coeffs:3 (1, 16, 31)
# Shape of wavelet_coeffs:4 (1, 32, 63)
# Shape of wavelet_coeffs:5 (1, 64, 127)
# Shape of wavelet_coeffs:6 (1, 128, 255)
# Shape of wavelet_coeffs:7 (1, 256, 511)
# Shape of wavelet_coeffs:8 (1, 512, 1023)
# Shape of wavelet_coeffs:9 (1, 1024, 2047)
# Shape of wavelet_coeffs:10 (1, 2048, 4095)
# Shape of wavelet_coeffs:11 (1, 2048, 4095)

# %%
# s2fft.inverse(stored_wavelet_coeffs, L_max)  # Test if the wavelet coefficients can be converted back to the MW map

# %%
# Stored_original_MW_map = np.load('data/MW_Map.npy')
# # is_real = np.isreal(original_healpix_map)
# is_real = np.isreal(Stored_original_MW_map)
# print(is_real.all()) 
#  setting reality=True in the context of spherical harmonic analysis indicates that the input data is real-valued, and the function leverages the conjugate symmetry property of the harmonic coefficients to optimize storage and computation.
# Out:
# False

# %%
plt.plot(filter[1])

# %%
reconstructed_MW_map_raw = s2wav.synthesis(stored_wavelet_coeffs, stored_scaling_coeffs, L_max, N_directions, filters=filter, reality = False)

reconstructed_MW_map = np.array(reconstructed_MW_map_raw)
np.save(f"convolution/reconstructed_MW_map", reconstructed_MW_map)  # Save numpy array to a file
stored_reconstructed_MW_map = np.load("convolution/reconstructed_MW_map.npy")

# %%
print(f"Mean absolute error = {np.nanmean(np.abs(reconstructed_MW_map_raw - original_MW_Map))}")
# Out:
# Mean absolute error = 5.027191403597514e-15

# %%
print(f"Mean absolute error = {np.nanmean(np.abs(stored_reconstructed_MW_map - stored_original_MW_map))}")
# Out:
# Mean absolute error = 5.027191403597514e-15

# %%
# Step 2: Perform spherical harmonic transform using s2fft
alm_reconstructed_MW_map = s2fft.forward(stored_reconstructed_MW_map, L_max)
np.save('data/alm_reconstructed_MW_map.npy', alm_reconstructed_MW_map)
stored_alm_reconstructed_MW_map = np.load('data/alm_reconstructed_MW_map.npy')

# %%
# Step 3: Rearrange coefficients for healpy
n_coeff = hp.Alm.getsize(L_max-1)
reconstructed_healpix_alm = np.zeros(n_coeff, dtype=np.complex128)

for l in range(L_max):
    for m in range(-l, l + 1):
        alm_index = hp.Alm.getidx(L_max - 1, l, abs(m))
        if alm_index >= n_coeff:
            print(f"Index {alm_index} is out of bounds for alm with size {n_coeff}")
            continue
        if m < 0:
            reconstructed_healpix_alm[alm_index] = (-1) ** m * np.conj(stored_alm_reconstructed_MW_map[l, L_max + m - 1])
        else:
            reconstructed_healpix_alm[alm_index] = stored_alm_reconstructed_MW_map[l, L_max + m - 1]

# %%
# Now `alm` is ready to be used with healpy
nside = L_max // 2
healpix_map = hp.alm2map(reconstructed_healpix_alm, nside, verbose=False)

# Save the HEALPix map to a FITS file
output_fits_path = 'reconstructed_healpix_map.fits'
hp.write_map(output_fits_path, healpix_map, overwrite=True, dtype=np.float64)

# %%
new_healpix_map = hp.read_map(output_fits_path)

# %%
# Create a new figure
fig = plt.figure(figsize=(30,10))

# Plot the new HEALPix map
ax1 = fig.add_subplot(1, 2, 1)
hp.mollview(
    original_healpix_map * 1e6,
    coord=["G"],
    title="New CMB at " + frequency + " GHz",
    unit=r"$\mu$K",
    min=-300,
    max=300,
    fig=fig,
    sub=(1, 2, 1)  # Subplot configuration
)

# Plot the original HEALPix map
ax2 = fig.add_subplot(1, 2, 2)
hp.mollview(
    new_healpix_map * 1e6,
    coord=["G"],
    title="Original CMB at " + frequency + " GHz",
    unit=r"$\mu$K",
    min=-300,
    max=300,
    fig=fig,
    sub=(1, 2, 2)  # Subplot configuration
)

plt.show()

# %%
import numpy as np
from mayavi import mlab
import s2wav
import s2fft
from s2fft.sampling import s2_samples as samples


"""
Requirements:
    - s2fft
    - s2wav
    - numpy 
    - mayavi 
"""

def plot_sphere(f: np.ndarray, L: int, sr: float, mx: float, mn: float):

    # Define meshgrid points on spherical surface
    phis = samples.phis_equiang(L, sampling="mw")
    thetas = samples.thetas(L, sampling="mw")

    # Fix continuity at boundaries for visualisation
    thetas[0] = 0
    phis[-1] = 2 * np.pi

    # Generate angular meshgrid
    phi, theta = np.meshgrid(phis, thetas)

    # Scaling to increase/decrease magnitude of coefficient for visualisation
    temp = (f - mn) / mx
    r = sr + temp

    # Convert angular meshgrid to cartesian
    x = r * np.sin(theta) * np.cos(phi)
    y = r * np.sin(theta) * np.sin(phi)
    z = r * np.cos(theta)

    # 3D render using mayavi package.
    mlab.figure(1, bgcolor=(1, 1, 1), fgcolor=(0, 0, 0), size=(300, 300))
    mlab.clf()
    mlab.mesh(x, y, z, scalars=temp, colormap="viridis",vmax=1-mn/mx,vmin=0)
    mlab.show()


# if __name__ == "__main__":
#     L = 128   # Harmonic bandlimit
#     N = 1     # Azimuthal bandlimit
#     sr = 5    # How much to scale the magnitude on the sphere for visualisation.

#     # Generate the wavelet kernel in spherical harmonic space
#     # Note: this generates the directional kernel, but the actual directionality is  
#     #       introduced during the convolution. So this is just a single set of harmonic
#     #       coefficients which you can imagine being rotated during the transform.
#     J_max = s2wav.samples.j_max(L)
#     wav_lmn, scal_lm = s2wav.filters.filters_directional_vectorised(L, N)

#     # Inverse spherical harmonic transform and plot the wavelet filters on the sphere.
#     for j in range(J_max):
#         wavelet_harmonic_coeffs = wav_lmn[j]
#         wavelet_coeffs = s2fft.inverse(wavelet_harmonic_coeffs, L)

        # mx, mn = np.nanmax(np.real(wavelet_coeffs)), np.nanmin(np.real(wavelet_coeffs))
        # plot_sphere(np.real(wavelet_pixel_space), L, sr, mx, mn)

# %%
print("wavelet",wavelet_coeffs.shape)
print("wavelet[0]",wavelet_coeffs[0].shape)
print("wavelet[0][0]",wavelet_coeffs[0][0].shape)
print("wavelet[1]",wavelet_coeffs[1].shape)
print("wavelet[1][1]",wavelet_coeffs[1][1].shape)
# Out:
# wavelet (128, 255)
# wavelet[0] (255,)
# wavelet[0][0] ()
# wavelet[1] (255,)
# wavelet[1][1] ()

# %%
for i in range(len(filter[0])):
    print(f"Shape of filter:{i} {filter[0][i].shape}")
for i in range(len(filter[1])):
    print(f"Shape of filter:{i} {filter[1][i].shape}")
# Out:
# Shape of filter:0 (2048, 4095)
# Shape of filter:1 (2048, 4095)
# Shape of filter:2 (2048, 4095)
# Shape of filter:3 (2048, 4095)
# Shape of filter:4 (2048, 4095)
# Shape of filter:5 (2048, 4095)
# Shape of filter:6 (2048, 4095)
# Shape of filter:7 (2048, 4095)
# Shape of filter:8 (2048, 4095)
# Shape of filter:9 (2048, 4095)
# Shape of filter:10 (2048, 4095)
# Shape of filter:11 (2048, 4095)
# Shape of filter:0 ()
# Shape of filter:1 ()
# Shape of filter:2 ()
# Shape of filter:3 ()
# Shape of filter:4 ()
# Shape of filter:5 ()
# Shape of filter:6 ()
# Shape of filter:7 ()
# Shape of filter:8 ()
# Shape of filter:9 ()
# Shape of filter:10 ()
# Shape of filter:11 ()
# Shape of filter:12 ()
# Shape of filter:13 ()
# Shape of filter:14 ()
# Shape of filter:15 ()
# Shape of filter:16 ()
# Shape of filter:17 ()
# Shape of filter:18 ()
# Shape of filter:19 ()
# Shape of filter:20 ()
# Shape of filter:21 ()
# Shape of filter:22 ()
# Shape of filter:23 ()
# Shape of filter:24 ()
# Shape of filter:25 ()
# Shape of filter:26 ()
# Shape of filter:27 ()
# Shape of filter:28 ()
# Shape of filter:29 ()
# Shape of filter:30 ()
# Shape of filter:31 ()
# Shape of filter:32 ()
# Shape of filter:33 ()
# Shape of filter:34 ()
# Shape of filter:35 ()
# Shape of filter:36 ()
# Shape of filter:37 ()
# Shape of filter:38 ()
# Shape of filter:39 ()
# Shape of filter:40 ()
# Shape of filter:41 ()
# Shape of filter:42 ()
# Shape of filter:43 ()
# Shape of filter:44 ()
# Shape of filter:45 ()
# Shape of filter:46 ()
# Shape of filter:47 ()
# Shape of filter:48 ()
# Shape of filter:49 ()
# Shape of filter:50 ()
# Shape of filter:51 ()
# Shape of filter:52 ()
# Shape of filter:53 ()
# Shape of filter:54 ()
# Shape of filter:55 ()
# Shape of filter:56 ()
# Shape of filter:57 ()
# Shape of filter:58 ()
# Shape of filter:59 ()
# Shape of filter:60 ()
# Shape of filter:61 ()
# Shape of filter:62 ()
# Shape of filter:63 ()
# Shape of filter:64 ()
# Shape of filter:65 ()
# Shape of filter:66 ()
# Shape of filter:67 ()
# Shape of filter:68 ()
# Shape of filter:69 ()
# Shape of filter:70 ()
# Shape of filter:71 ()
# Shape of filter:72 ()
# Shape of filter:73 ()
# Shape of filter:74 ()
# Shape of filter:75 ()
# Shape of filter:76 ()
# Shape of filter:77 ()
# Shape of filter:78 ()
# Shape of filter:79 ()
# Shape of filter:80 ()
# Shape of filter:81 ()
# Shape of filter:82 ()
# Shape of filter:83 ()
# Shape of filter:84 ()
# Shape of filter:85 ()
# Shape of filter:86 ()
# Shape of filter:87 ()
# Shape of filter:88 ()
# Shape of filter:89 ()
# Shape of filter:90 ()
# Shape of filter:91 ()
# Shape of filter:92 ()
# Shape of filter:93 ()
# Shape of filter:94 ()
# Shape of filter:95 ()
# Shape of filter:96 ()
# Shape of filter:97 ()
# Shape of filter:98 ()
# Shape of filter:99 ()
# Shape of filter:100 ()
# Shape of filter:101 ()
# Shape of filter:102 ()
# Shape of filter:103 ()
# Shape of filter:104 ()
# Shape of filter:105 ()
# Shape of filter:106 ()
# Shape of filter:107 ()
# Shape of filter:108 ()
# Shape of filter:109 ()
# Shape of filter:110 ()
# Shape of filter:111 ()
# Shape of filter:112 ()
# Shape of filter:113 ()
# Shape of filter:114 ()
# Shape of filter:115 ()
# Shape of filter:116 ()
# Shape of filter:117 ()
# Shape of filter:118 ()
# Shape of filter:119 ()
# Shape of filter:120 ()
# Shape of filter:121 ()
# Shape of filter:122 ()
# Shape of filter:123 ()
# Shape of filter:124 ()
# Shape of filter:125 ()
# Shape of filter:126 ()
# Shape of filter:127 ()
# Shape of filter:128 ()
# Shape of filter:129 ()
# Shape of filter:130 ()
# Shape of filter:131 ()
# Shape of filter:132 ()
# Shape of filter:133 ()
# Shape of filter:134 ()
# Shape of filter:135 ()
# Shape of filter:136 ()
# Shape of filter:137 ()
# Shape of filter:138 ()
# Shape of filter:139 ()
# Shape of filter:140 ()
# Shape of filter:141 ()
# Shape of filter:142 ()
# Shape of filter:143 ()
# Shape of filter:144 ()
# Shape of filter:145 ()
# Shape of filter:146 ()
# Shape of filter:147 ()
# Shape of filter:148 ()
# Shape of filter:149 ()
# Shape of filter:150 ()
# Shape of filter:151 ()
# Shape of filter:152 ()
# Shape of filter:153 ()
# Shape of filter:154 ()
# Shape of filter:155 ()
# Shape of filter:156 ()
# Shape of filter:157 ()
# Shape of filter:158 ()
# Shape of filter:159 ()
# Shape of filter:160 ()
# Shape of filter:161 ()
# Shape of filter:162 ()
# Shape of filter:163 ()
# Shape of filter:164 ()
# Shape of filter:165 ()
# Shape of filter:166 ()
# Shape of filter:167 ()
# Shape of filter:168 ()
# Shape of filter:169 ()
# Shape of filter:170 ()
# Shape of filter:171 ()
# Shape of filter:172 ()
# Shape of filter:173 ()
# Shape of filter:174 ()
# Shape of filter:175 ()
# Shape of filter:176 ()
# Shape of filter:177 ()
# Shape of filter:178 ()
# Shape of filter:179 ()
# Shape of filter:180 ()
# Shape of filter:181 ()
# Shape of filter:182 ()
# Shape of filter:183 ()
# Shape of filter:184 ()
# Shape of filter:185 ()
# Shape of filter:186 ()
# Shape of filter:187 ()
# Shape of filter:188 ()
# Shape of filter:189 ()
# Shape of filter:190 ()
# Shape of filter:191 ()
# Shape of filter:192 ()
# Shape of filter:193 ()
# Shape of filter:194 ()
# Shape of filter:195 ()
# Shape of filter:196 ()
# Shape of filter:197 ()
# Shape of filter:198 ()
# Shape of filter:199 ()
# Shape of filter:200 ()
# Shape of filter:201 ()
# Shape of filter:202 ()
# Shape of filter:203 ()
# Shape of filter:204 ()
# Shape of filter:205 ()
# Shape of filter:206 ()
# Shape of filter:207 ()
# Shape of filter:208 ()
# Shape of filter:209 ()
# Shape of filter:210 ()
# Shape of filter:211 ()
# Shape of filter:212 ()
# Shape of filter:213 ()
# Shape of filter:214 ()
# Shape of filter:215 ()
# Shape of filter:216 ()
# Shape of filter:217 ()
# Shape of filter:218 ()
# Shape of filter:219 ()
# Shape of filter:220 ()
# Shape of filter:221 ()
# Shape of filter:222 ()
# Shape of filter:223 ()
# Shape of filter:224 ()
# Shape of filter:225 ()
# Shape of filter:226 ()
# Shape of filter:227 ()
# Shape of filter:228 ()
# Shape of filter:229 ()
# Shape of filter:230 ()
# Shape of filter:231 ()
# Shape of filter:232 ()
# Shape of filter:233 ()
# Shape of filter:234 ()
# Shape of filter:235 ()
# Shape of filter:236 ()
# Shape of filter:237 ()
# Shape of filter:238 ()
# Shape of filter:239 ()
# Shape of filter:240 ()
# Shape of filter:241 ()
# Shape of filter:242 ()
# Shape of filter:243 ()
# Shape of filter:244 ()
# Shape of filter:245 ()
# Shape of filter:246 ()
# Shape of filter:247 ()
# Shape of filter:248 ()
# Shape of filter:249 ()
# Shape of filter:250 ()
# Shape of filter:251 ()
# Shape of filter:252 ()
# Shape of filter:253 ()
# Shape of filter:254 ()
# Shape of filter:255 ()
# Shape of filter:256 ()
# Shape of filter:257 ()
# Shape of filter:258 ()
# Shape of filter:259 ()
# Shape of filter:260 ()
# Shape of filter:261 ()
# Shape of filter:262 ()
# Shape of filter:263 ()
# Shape of filter:264 ()
# Shape of filter:265 ()
# Shape of filter:266 ()
# Shape of filter:267 ()
# Shape of filter:268 ()
# Shape of filter:269 ()
# Shape of filter:270 ()
# Shape of filter:271 ()
# Shape of filter:272 ()
# Shape of filter:273 ()
# Shape of filter:274 ()
# Shape of filter:275 ()
# Shape of filter:276 ()
# Shape of filter:277 ()
# Shape of filter:278 ()
# Shape of filter:279 ()
# Shape of filter:280 ()
# Shape of filter:281 ()
# Shape of filter:282 ()
# Shape of filter:283 ()
# Shape of filter:284 ()
# Shape of filter:285 ()
# Shape of filter:286 ()
# Shape of filter:287 ()
# Shape of filter:288 ()
# Shape of filter:289 ()
# Shape of filter:290 ()
# Shape of filter:291 ()
# Shape of filter:292 ()
# Shape of filter:293 ()
# Shape of filter:294 ()
# Shape of filter:295 ()
# Shape of filter:296 ()
# Shape of filter:297 ()
# Shape of filter:298 ()
# Shape of filter:299 ()
# Shape of filter:300 ()
# Shape of filter:301 ()
# Shape of filter:302 ()
# Shape of filter:303 ()
# Shape of filter:304 ()
# Shape of filter:305 ()
# Shape of filter:306 ()
# Shape of filter:307 ()
# Shape of filter:308 ()
# Shape of filter:309 ()
# Shape of filter:310 ()
# Shape of filter:311 ()
# Shape of filter:312 ()
# Shape of filter:313 ()
# Shape of filter:314 ()
# Shape of filter:315 ()
# Shape of filter:316 ()
# Shape of filter:317 ()
# Shape of filter:318 ()
# Shape of filter:319 ()
# Shape of filter:320 ()
# Shape of filter:321 ()
# Shape of filter:322 ()
# Shape of filter:323 ()
# Shape of filter:324 ()
# Shape of filter:325 ()
# Shape of filter:326 ()
# Shape of filter:327 ()
# Shape of filter:328 ()
# Shape of filter:329 ()
# Shape of filter:330 ()
# Shape of filter:331 ()
# Shape of filter:332 ()
# Shape of filter:333 ()
# Shape of filter:334 ()
# Shape of filter:335 ()
# Shape of filter:336 ()
# Shape of filter:337 ()
# Shape of filter:338 ()
# Shape of filter:339 ()
# Shape of filter:340 ()
# Shape of filter:341 ()
# Shape of filter:342 ()
# Shape of filter:343 ()
# Shape of filter:344 ()
# Shape of filter:345 ()
# Shape of filter:346 ()
# Shape of filter:347 ()
# Shape of filter:348 ()
# Shape of filter:349 ()
# Shape of filter:350 ()
# Shape of filter:351 ()
# Shape of filter:352 ()
# Shape of filter:353 ()
# Shape of filter:354 ()
# Shape of filter:355 ()
# Shape of filter:356 ()
# Shape of filter:357 ()
# Shape of filter:358 ()
# Shape of filter:359 ()
# Shape of filter:360 ()
# Shape of filter:361 ()
# Shape of filter:362 ()
# Shape of filter:363 ()
# Shape of filter:364 ()
# Shape of filter:365 ()
# Shape of filter:366 ()
# Shape of filter:367 ()
# Shape of filter:368 ()
# Shape of filter:369 ()
# Shape of filter:370 ()
# Shape of filter:371 ()
# Shape of filter:372 ()
# Shape of filter:373 ()
# Shape of filter:374 ()
# Shape of filter:375 ()
# Shape of filter:376 ()
# Shape of filter:377 ()
# Shape of filter:378 ()
# Shape of filter:379 ()
# Shape of filter:380 ()
# Shape of filter:381 ()
# Shape of filter:382 ()
# Shape of filter:383 ()
# Shape of filter:384 ()
# Shape of filter:385 ()
# Shape of filter:386 ()
# Shape of filter:387 ()
# Shape of filter:388 ()
# Shape of filter:389 ()
# Shape of filter:390 ()
# Shape of filter:391 ()
# Shape of filter:392 ()
# Shape of filter:393 ()
# Shape of filter:394 ()
# Shape of filter:395 ()
# Shape of filter:396 ()
# Shape of filter:397 ()
# Shape of filter:398 ()
# Shape of filter:399 ()
# Shape of filter:400 ()
# Shape of filter:401 ()
# Shape of filter:402 ()
# Shape of filter:403 ()
# Shape of filter:404 ()
# Shape of filter:405 ()
# Shape of filter:406 ()
# Shape of filter:407 ()
# Shape of filter:408 ()
# Shape of filter:409 ()
# Shape of filter:410 ()
# Shape of filter:411 ()
# Shape of filter:412 ()
# Shape of filter:413 ()
# Shape of filter:414 ()
# Shape of filter:415 ()
# Shape of filter:416 ()
# Shape of filter:417 ()
# Shape of filter:418 ()
# Shape of filter:419 ()
# Shape of filter:420 ()
# Shape of filter:421 ()
# Shape of filter:422 ()
# Shape of filter:423 ()
# Shape of filter:424 ()
# Shape of filter:425 ()
# Shape of filter:426 ()
# Shape of filter:427 ()
# Shape of filter:428 ()
# Shape of filter:429 ()
# Shape of filter:430 ()
# Shape of filter:431 ()
# Shape of filter:432 ()
# Shape of filter:433 ()
# Shape of filter:434 ()
# Shape of filter:435 ()
# Shape of filter:436 ()
# Shape of filter:437 ()
# Shape of filter:438 ()
# Shape of filter:439 ()
# Shape of filter:440 ()
# Shape of filter:441 ()
# Shape of filter:442 ()
# Shape of filter:443 ()
# Shape of filter:444 ()
# Shape of filter:445 ()
# Shape of filter:446 ()
# Shape of filter:447 ()
# Shape of filter:448 ()
# Shape of filter:449 ()
# Shape of filter:450 ()
# Shape of filter:451 ()
# Shape of filter:452 ()
# Shape of filter:453 ()
# Shape of filter:454 ()
# Shape of filter:455 ()
# Shape of filter:456 ()
# Shape of filter:457 ()
# Shape of filter:458 ()
# Shape of filter:459 ()
# Shape of filter:460 ()
# Shape of filter:461 ()
# Shape of filter:462 ()
# Shape of filter:463 ()
# Shape of filter:464 ()
# Shape of filter:465 ()
# Shape of filter:466 ()
# Shape of filter:467 ()
# Shape of filter:468 ()
# Shape of filter:469 ()
# Shape of filter:470 ()
# Shape of filter:471 ()
# Shape of filter:472 ()
# Shape of filter:473 ()
# Shape of filter:474 ()
# Shape of filter:475 ()
# Shape of filter:476 ()
# Shape of filter:477 ()
# Shape of filter:478 ()
# Shape of filter:479 ()
# Shape of filter:480 ()
# Shape of filter:481 ()
# Shape of filter:482 ()
# Shape of filter:483 ()
# Shape of filter:484 ()
# Shape of filter:485 ()
# Shape of filter:486 ()
# Shape of filter:487 ()
# Shape of filter:488 ()
# Shape of filter:489 ()
# Shape of filter:490 ()
# Shape of filter:491 ()
# Shape of filter:492 ()
# Shape of filter:493 ()
# Shape of filter:494 ()
# Shape of filter:495 ()
# Shape of filter:496 ()
# Shape of filter:497 ()
# Shape of filter:498 ()
# Shape of filter:499 ()
# Shape of filter:500 ()
# Shape of filter:501 ()
# Shape of filter:502 ()
# Shape of filter:503 ()
# Shape of filter:504 ()
# Shape of filter:505 ()
# Shape of filter:506 ()
# Shape of filter:507 ()
# Shape of filter:508 ()
# Shape of filter:509 ()
# Shape of filter:510 ()
# Shape of filter:511 ()
# Shape of filter:512 ()
# Shape of filter:513 ()
# Shape of filter:514 ()
# Shape of filter:515 ()
# Shape of filter:516 ()
# Shape of filter:517 ()
# Shape of filter:518 ()
# Shape of filter:519 ()
# Shape of filter:520 ()
# Shape of filter:521 ()
# Shape of filter:522 ()
# Shape of filter:523 ()
# Shape of filter:524 ()
# Shape of filter:525 ()
# Shape of filter:526 ()
# Shape of filter:527 ()
# Shape of filter:528 ()
# Shape of filter:529 ()
# Shape of filter:530 ()
# Shape of filter:531 ()
# Shape of filter:532 ()
# Shape of filter:533 ()
# Shape of filter:534 ()
# Shape of filter:535 ()
# Shape of filter:536 ()
# Shape of filter:537 ()
# Shape of filter:538 ()
# Shape of filter:539 ()
# Shape of filter:540 ()
# Shape of filter:541 ()
# Shape of filter:542 ()
# Shape of filter:543 ()
# Shape of filter:544 ()
# Shape of filter:545 ()
# Shape of filter:546 ()
# Shape of filter:547 ()
# Shape of filter:548 ()
# Shape of filter:549 ()
# Shape of filter:550 ()
# Shape of filter:551 ()
# Shape of filter:552 ()
# Shape of filter:553 ()
# Shape of filter:554 ()
# Shape of filter:555 ()
# Shape of filter:556 ()
# Shape of filter:557 ()
# Shape of filter:558 ()
# Shape of filter:559 ()
# Shape of filter:560 ()
# Shape of filter:561 ()
# Shape of filter:562 ()
# Shape of filter:563 ()
# Shape of filter:564 ()
# Shape of filter:565 ()
# Shape of filter:566 ()
# Shape of filter:567 ()
# Shape of filter:568 ()
# Shape of filter:569 ()
# Shape of filter:570 ()
# Shape of filter:571 ()
# Shape of filter:572 ()
# Shape of filter:573 ()
# Shape of filter:574 ()
# Shape of filter:575 ()
# Shape of filter:576 ()
# Shape of filter:577 ()
# Shape of filter:578 ()
# Shape of filter:579 ()
# Shape of filter:580 ()
# Shape of filter:581 ()
# Shape of filter:582 ()
# Shape of filter:583 ()
# Shape of filter:584 ()
# Shape of filter:585 ()
# Shape of filter:586 ()
# Shape of filter:587 ()
# Shape of filter:588 ()
# Shape of filter:589 ()
# Shape of filter:590 ()
# Shape of filter:591 ()
# Shape of filter:592 ()
# Shape of filter:593 ()
# Shape of filter:594 ()
# Shape of filter:595 ()
# Shape of filter:596 ()
# Shape of filter:597 ()
# Shape of filter:598 ()
# Shape of filter:599 ()
# Shape of filter:600 ()
# Shape of filter:601 ()
# Shape of filter:602 ()
# Shape of filter:603 ()
# Shape of filter:604 ()
# Shape of filter:605 ()
# Shape of filter:606 ()
# Shape of filter:607 ()
# Shape of filter:608 ()
# Shape of filter:609 ()
# Shape of filter:610 ()
# Shape of filter:611 ()
# Shape of filter:612 ()
# Shape of filter:613 ()
# Shape of filter:614 ()
# Shape of filter:615 ()
# Shape of filter:616 ()
# Shape of filter:617 ()
# Shape of filter:618 ()
# Shape of filter:619 ()
# Shape of filter:620 ()
# Shape of filter:621 ()
# Shape of filter:622 ()
# Shape of filter:623 ()
# Shape of filter:624 ()
# Shape of filter:625 ()
# Shape of filter:626 ()
# Shape of filter:627 ()
# Shape of filter:628 ()
# Shape of filter:629 ()
# Shape of filter:630 ()
# Shape of filter:631 ()
# Shape of filter:632 ()
# Shape of filter:633 ()
# Shape of filter:634 ()
# Shape of filter:635 ()
# Shape of filter:636 ()
# Shape of filter:637 ()
# Shape of filter:638 ()
# Shape of filter:639 ()
# Shape of filter:640 ()
# Shape of filter:641 ()
# Shape of filter:642 ()
# Shape of filter:643 ()
# Shape of filter:644 ()
# Shape of filter:645 ()
# Shape of filter:646 ()
# Shape of filter:647 ()
# Shape of filter:648 ()
# Shape of filter:649 ()
# Shape of filter:650 ()
# Shape of filter:651 ()
# Shape of filter:652 ()
# Shape of filter:653 ()
# Shape of filter:654 ()
# Shape of filter:655 ()
# Shape of filter:656 ()
# Shape of filter:657 ()
# Shape of filter:658 ()
# Shape of filter:659 ()
# Shape of filter:660 ()
# Shape of filter:661 ()
# Shape of filter:662 ()
# Shape of filter:663 ()
# Shape of filter:664 ()
# Shape of filter:665 ()
# Shape of filter:666 ()
# Shape of filter:667 ()
# Shape of filter:668 ()
# Shape of filter:669 ()
# Shape of filter:670 ()
# Shape of filter:671 ()
# Shape of filter:672 ()
# Shape of filter:673 ()
# Shape of filter:674 ()
# Shape of filter:675 ()
# Shape of filter:676 ()
# Shape of filter:677 ()
# Shape of filter:678 ()
# Shape of filter:679 ()
# Shape of filter:680 ()
# Shape of filter:681 ()
# Shape of filter:682 ()
# Shape of filter:683 ()
# Shape of filter:684 ()
# Shape of filter:685 ()
# Shape of filter:686 ()
# Shape of filter:687 ()
# Shape of filter:688 ()
# Shape of filter:689 ()
# Shape of filter:690 ()
# Shape of filter:691 ()
# Shape of filter:692 ()
# Shape of filter:693 ()
# Shape of filter:694 ()
# Shape of filter:695 ()
# Shape of filter:696 ()
# Shape of filter:697 ()
# Shape of filter:698 ()
# Shape of filter:699 ()
# Shape of filter:700 ()
# Shape of filter:701 ()
# Shape of filter:702 ()
# Shape of filter:703 ()
# Shape of filter:704 ()
# Shape of filter:705 ()
# Shape of filter:706 ()
# Shape of filter:707 ()
# Shape of filter:708 ()
# Shape of filter:709 ()
# Shape of filter:710 ()
# Shape of filter:711 ()
# Shape of filter:712 ()
# Shape of filter:713 ()
# Shape of filter:714 ()
# Shape of filter:715 ()
# Shape of filter:716 ()
# Shape of filter:717 ()
# Shape of filter:718 ()
# Shape of filter:719 ()
# Shape of filter:720 ()
# Shape of filter:721 ()
# Shape of filter:722 ()
# Shape of filter:723 ()
# Shape of filter:724 ()
# Shape of filter:725 ()
# Shape of filter:726 ()
# Shape of filter:727 ()
# Shape of filter:728 ()
# Shape of filter:729 ()
# Shape of filter:730 ()
# Shape of filter:731 ()
# Shape of filter:732 ()
# Shape of filter:733 ()
# Shape of filter:734 ()
# Shape of filter:735 ()
# Shape of filter:736 ()
# Shape of filter:737 ()
# Shape of filter:738 ()
# Shape of filter:739 ()
# Shape of filter:740 ()
# Shape of filter:741 ()
# Shape of filter:742 ()
# Shape of filter:743 ()
# Shape of filter:744 ()
# Shape of filter:745 ()
# Shape of filter:746 ()
# Shape of filter:747 ()
# Shape of filter:748 ()
# Shape of filter:749 ()
# Shape of filter:750 ()
# Shape of filter:751 ()
# Shape of filter:752 ()
# Shape of filter:753 ()
# Shape of filter:754 ()
# Shape of filter:755 ()
# Shape of filter:756 ()
# Shape of filter:757 ()
# Shape of filter:758 ()
# Shape of filter:759 ()
# Shape of filter:760 ()
# Shape of filter:761 ()
# Shape of filter:762 ()
# Shape of filter:763 ()
# Shape of filter:764 ()
# Shape of filter:765 ()
# Shape of filter:766 ()
# Shape of filter:767 ()
# Shape of filter:768 ()
# Shape of filter:769 ()
# Shape of filter:770 ()
# Shape of filter:771 ()
# Shape of filter:772 ()
# Shape of filter:773 ()
# Shape of filter:774 ()
# Shape of filter:775 ()
# Shape of filter:776 ()
# Shape of filter:777 ()
# Shape of filter:778 ()
# Shape of filter:779 ()
# Shape of filter:780 ()
# Shape of filter:781 ()
# Shape of filter:782 ()
# Shape of filter:783 ()
# Shape of filter:784 ()
# Shape of filter:785 ()
# Shape of filter:786 ()
# Shape of filter:787 ()
# Shape of filter:788 ()
# Shape of filter:789 ()
# Shape of filter:790 ()
# Shape of filter:791 ()
# Shape of filter:792 ()
# Shape of filter:793 ()
# Shape of filter:794 ()
# Shape of filter:795 ()
# Shape of filter:796 ()
# Shape of filter:797 ()
# Shape of filter:798 ()
# Shape of filter:799 ()
# Shape of filter:800 ()
# Shape of filter:801 ()
# Shape of filter:802 ()
# Shape of filter:803 ()
# Shape of filter:804 ()
# Shape of filter:805 ()
# Shape of filter:806 ()
# Shape of filter:807 ()
# Shape of filter:808 ()
# Shape of filter:809 ()
# Shape of filter:810 ()
# Shape of filter:811 ()
# Shape of filter:812 ()
# Shape of filter:813 ()
# Shape of filter:814 ()
# Shape of filter:815 ()
# Shape of filter:816 ()
# Shape of filter:817 ()
# Shape of filter:818 ()
# Shape of filter:819 ()
# Shape of filter:820 ()
# Shape of filter:821 ()
# Shape of filter:822 ()
# Shape of filter:823 ()
# Shape of filter:824 ()
# Shape of filter:825 ()
# Shape of filter:826 ()
# Shape of filter:827 ()
# Shape of filter:828 ()
# Shape of filter:829 ()
# Shape of filter:830 ()
# Shape of filter:831 ()
# Shape of filter:832 ()
# Shape of filter:833 ()
# Shape of filter:834 ()
# Shape of filter:835 ()
# Shape of filter:836 ()
# Shape of filter:837 ()
# Shape of filter:838 ()
# Shape of filter:839 ()
# Shape of filter:840 ()
# Shape of filter:841 ()
# Shape of filter:842 ()
# Shape of filter:843 ()
# Shape of filter:844 ()
# Shape of filter:845 ()
# Shape of filter:846 ()
# Shape of filter:847 ()
# Shape of filter:848 ()
# Shape of filter:849 ()
# Shape of filter:850 ()
# Shape of filter:851 ()
# Shape of filter:852 ()
# Shape of filter:853 ()
# Shape of filter:854 ()
# Shape of filter:855 ()
# Shape of filter:856 ()
# Shape of filter:857 ()
# Shape of filter:858 ()
# Shape of filter:859 ()
# Shape of filter:860 ()
# Shape of filter:861 ()
# Shape of filter:862 ()
# Shape of filter:863 ()
# Shape of filter:864 ()
# Shape of filter:865 ()
# Shape of filter:866 ()
# Shape of filter:867 ()
# Shape of filter:868 ()
# Shape of filter:869 ()
# Shape of filter:870 ()
# Shape of filter:871 ()
# Shape of filter:872 ()
# Shape of filter:873 ()
# Shape of filter:874 ()
# Shape of filter:875 ()
# Shape of filter:876 ()
# Shape of filter:877 ()
# Shape of filter:878 ()
# Shape of filter:879 ()
# Shape of filter:880 ()
# Shape of filter:881 ()
# Shape of filter:882 ()
# Shape of filter:883 ()
# Shape of filter:884 ()
# Shape of filter:885 ()
# Shape of filter:886 ()
# Shape of filter:887 ()
# Shape of filter:888 ()
# Shape of filter:889 ()
# Shape of filter:890 ()
# Shape of filter:891 ()
# Shape of filter:892 ()
# Shape of filter:893 ()
# Shape of filter:894 ()
# Shape of filter:895 ()
# Shape of filter:896 ()
# Shape of filter:897 ()
# Shape of filter:898 ()
# Shape of filter:899 ()
# Shape of filter:900 ()
# Shape of filter:901 ()
# Shape of filter:902 ()
# Shape of filter:903 ()
# Shape of filter:904 ()
# Shape of filter:905 ()
# Shape of filter:906 ()
# Shape of filter:907 ()
# Shape of filter:908 ()
# Shape of filter:909 ()
# Shape of filter:910 ()
# Shape of filter:911 ()
# Shape of filter:912 ()
# Shape of filter:913 ()
# Shape of filter:914 ()
# Shape of filter:915 ()
# Shape of filter:916 ()
# Shape of filter:917 ()
# Shape of filter:918 ()
# Shape of filter:919 ()
# Shape of filter:920 ()
# Shape of filter:921 ()
# Shape of filter:922 ()
# Shape of filter:923 ()
# Shape of filter:924 ()
# Shape of filter:925 ()
# Shape of filter:926 ()
# Shape of filter:927 ()
# Shape of filter:928 ()
# Shape of filter:929 ()
# Shape of filter:930 ()
# Shape of filter:931 ()
# Shape of filter:932 ()
# Shape of filter:933 ()
# Shape of filter:934 ()
# Shape of filter:935 ()
# Shape of filter:936 ()
# Shape of filter:937 ()
# Shape of filter:938 ()
# Shape of filter:939 ()
# Shape of filter:940 ()
# Shape of filter:941 ()
# Shape of filter:942 ()
# Shape of filter:943 ()
# Shape of filter:944 ()
# Shape of filter:945 ()
# Shape of filter:946 ()
# Shape of filter:947 ()
# Shape of filter:948 ()
# Shape of filter:949 ()
# Shape of filter:950 ()
# Shape of filter:951 ()
# Shape of filter:952 ()
# Shape of filter:953 ()
# Shape of filter:954 ()
# Shape of filter:955 ()
# Shape of filter:956 ()
# Shape of filter:957 ()
# Shape of filter:958 ()
# Shape of filter:959 ()
# Shape of filter:960 ()
# Shape of filter:961 ()
# Shape of filter:962 ()
# Shape of filter:963 ()
# Shape of filter:964 ()
# Shape of filter:965 ()
# Shape of filter:966 ()
# Shape of filter:967 ()
# Shape of filter:968 ()
# Shape of filter:969 ()
# Shape of filter:970 ()
# Shape of filter:971 ()
# Shape of filter:972 ()
# Shape of filter:973 ()
# Shape of filter:974 ()
# Shape of filter:975 ()
# Shape of filter:976 ()
# Shape of filter:977 ()
# Shape of filter:978 ()
# Shape of filter:979 ()
# Shape of filter:980 ()
# Shape of filter:981 ()
# Shape of filter:982 ()
# Shape of filter:983 ()
# Shape of filter:984 ()
# Shape of filter:985 ()
# Shape of filter:986 ()
# Shape of filter:987 ()
# Shape of filter:988 ()
# Shape of filter:989 ()
# Shape of filter:990 ()
# Shape of filter:991 ()
# Shape of filter:992 ()
# Shape of filter:993 ()
# Shape of filter:994 ()
# Shape of filter:995 ()
# Shape of filter:996 ()
# Shape of filter:997 ()
# Shape of filter:998 ()
# Shape of filter:999 ()
# Shape of filter:1000 ()
# Shape of filter:1001 ()
# Shape of filter:1002 ()
# Shape of filter:1003 ()
# Shape of filter:1004 ()
# Shape of filter:1005 ()
# Shape of filter:1006 ()
# Shape of filter:1007 ()
# Shape of filter:1008 ()
# Shape of filter:1009 ()
# Shape of filter:1010 ()
# Shape of filter:1011 ()
# Shape of filter:1012 ()
# Shape of filter:1013 ()
# Shape of filter:1014 ()
# Shape of filter:1015 ()
# Shape of filter:1016 ()
# Shape of filter:1017 ()
# Shape of filter:1018 ()
# Shape of filter:1019 ()
# Shape of filter:1020 ()
# Shape of filter:1021 ()
# Shape of filter:1022 ()
# Shape of filter:1023 ()
# Shape of filter:1024 ()
# Shape of filter:1025 ()
# Shape of filter:1026 ()
# Shape of filter:1027 ()
# Shape of filter:1028 ()
# Shape of filter:1029 ()
# Shape of filter:1030 ()
# Shape of filter:1031 ()
# Shape of filter:1032 ()
# Shape of filter:1033 ()
# Shape of filter:1034 ()
# Shape of filter:1035 ()
# Shape of filter:1036 ()
# Shape of filter:1037 ()
# Shape of filter:1038 ()
# Shape of filter:1039 ()
# Shape of filter:1040 ()
# Shape of filter:1041 ()
# Shape of filter:1042 ()
# Shape of filter:1043 ()
# Shape of filter:1044 ()
# Shape of filter:1045 ()
# Shape of filter:1046 ()
# Shape of filter:1047 ()
# Shape of filter:1048 ()
# Shape of filter:1049 ()
# Shape of filter:1050 ()
# Shape of filter:1051 ()
# Shape of filter:1052 ()
# Shape of filter:1053 ()
# Shape of filter:1054 ()
# Shape of filter:1055 ()
# Shape of filter:1056 ()
# Shape of filter:1057 ()
# Shape of filter:1058 ()
# Shape of filter:1059 ()
# Shape of filter:1060 ()
# Shape of filter:1061 ()
# Shape of filter:1062 ()
# Shape of filter:1063 ()
# Shape of filter:1064 ()
# Shape of filter:1065 ()
# Shape of filter:1066 ()
# Shape of filter:1067 ()
# Shape of filter:1068 ()
# Shape of filter:1069 ()
# Shape of filter:1070 ()
# Shape of filter:1071 ()
# Shape of filter:1072 ()
# Shape of filter:1073 ()
# Shape of filter:1074 ()
# Shape of filter:1075 ()
# Shape of filter:1076 ()
# Shape of filter:1077 ()
# Shape of filter:1078 ()
# Shape of filter:1079 ()
# Shape of filter:1080 ()
# Shape of filter:1081 ()
# Shape of filter:1082 ()
# Shape of filter:1083 ()
# Shape of filter:1084 ()
# Shape of filter:1085 ()
# Shape of filter:1086 ()
# Shape of filter:1087 ()
# Shape of filter:1088 ()
# Shape of filter:1089 ()
# Shape of filter:1090 ()
# Shape of filter:1091 ()
# Shape of filter:1092 ()
# Shape of filter:1093 ()
# Shape of filter:1094 ()
# Shape of filter:1095 ()
# Shape of filter:1096 ()
# Shape of filter:1097 ()
# Shape of filter:1098 ()
# Shape of filter:1099 ()
# Shape of filter:1100 ()
# Shape of filter:1101 ()
# Shape of filter:1102 ()
# Shape of filter:1103 ()
# Shape of filter:1104 ()
# Shape of filter:1105 ()
# Shape of filter:1106 ()
# Shape of filter:1107 ()
# Shape of filter:1108 ()
# Shape of filter:1109 ()
# Shape of filter:1110 ()
# Shape of filter:1111 ()
# Shape of filter:1112 ()
# Shape of filter:1113 ()
# Shape of filter:1114 ()
# Shape of filter:1115 ()
# Shape of filter:1116 ()
# Shape of filter:1117 ()
# Shape of filter:1118 ()
# Shape of filter:1119 ()
# Shape of filter:1120 ()
# Shape of filter:1121 ()
# Shape of filter:1122 ()
# Shape of filter:1123 ()
# Shape of filter:1124 ()
# Shape of filter:1125 ()
# Shape of filter:1126 ()
# Shape of filter:1127 ()
# Shape of filter:1128 ()
# Shape of filter:1129 ()
# Shape of filter:1130 ()
# Shape of filter:1131 ()
# Shape of filter:1132 ()
# Shape of filter:1133 ()
# Shape of filter:1134 ()
# Shape of filter:1135 ()
# Shape of filter:1136 ()
# Shape of filter:1137 ()
# Shape of filter:1138 ()
# Shape of filter:1139 ()
# Shape of filter:1140 ()
# Shape of filter:1141 ()
# Shape of filter:1142 ()
# Shape of filter:1143 ()
# Shape of filter:1144 ()
# Shape of filter:1145 ()
# Shape of filter:1146 ()
# Shape of filter:1147 ()
# Shape of filter:1148 ()
# Shape of filter:1149 ()
# Shape of filter:1150 ()
# Shape of filter:1151 ()
# Shape of filter:1152 ()
# Shape of filter:1153 ()
# Shape of filter:1154 ()
# Shape of filter:1155 ()
# Shape of filter:1156 ()
# Shape of filter:1157 ()
# Shape of filter:1158 ()
# Shape of filter:1159 ()
# Shape of filter:1160 ()
# Shape of filter:1161 ()
# Shape of filter:1162 ()
# Shape of filter:1163 ()
# Shape of filter:1164 ()
# Shape of filter:1165 ()
# Shape of filter:1166 ()
# Shape of filter:1167 ()
# Shape of filter:1168 ()
# Shape of filter:1169 ()
# Shape of filter:1170 ()
# Shape of filter:1171 ()
# Shape of filter:1172 ()
# Shape of filter:1173 ()
# Shape of filter:1174 ()
# Shape of filter:1175 ()
# Shape of filter:1176 ()
# Shape of filter:1177 ()
# Shape of filter:1178 ()
# Shape of filter:1179 ()
# Shape of filter:1180 ()
# Shape of filter:1181 ()
# Shape of filter:1182 ()
# Shape of filter:1183 ()
# Shape of filter:1184 ()
# Shape of filter:1185 ()
# Shape of filter:1186 ()
# Shape of filter:1187 ()
# Shape of filter:1188 ()
# Shape of filter:1189 ()
# Shape of filter:1190 ()
# Shape of filter:1191 ()
# Shape of filter:1192 ()
# Shape of filter:1193 ()
# Shape of filter:1194 ()
# Shape of filter:1195 ()
# Shape of filter:1196 ()
# Shape of filter:1197 ()
# Shape of filter:1198 ()
# Shape of filter:1199 ()
# Shape of filter:1200 ()
# Shape of filter:1201 ()
# Shape of filter:1202 ()
# Shape of filter:1203 ()
# Shape of filter:1204 ()
# Shape of filter:1205 ()
# Shape of filter:1206 ()
# Shape of filter:1207 ()
# Shape of filter:1208 ()
# Shape of filter:1209 ()
# Shape of filter:1210 ()
# Shape of filter:1211 ()
# Shape of filter:1212 ()
# Shape of filter:1213 ()
# Shape of filter:1214 ()
# Shape of filter:1215 ()
# Shape of filter:1216 ()
# Shape of filter:1217 ()
# Shape of filter:1218 ()
# Shape of filter:1219 ()
# Shape of filter:1220 ()
# Shape of filter:1221 ()
# Shape of filter:1222 ()
# Shape of filter:1223 ()
# Shape of filter:1224 ()
# Shape of filter:1225 ()
# Shape of filter:1226 ()
# Shape of filter:1227 ()
# Shape of filter:1228 ()
# Shape of filter:1229 ()
# Shape of filter:1230 ()
# Shape of filter:1231 ()
# Shape of filter:1232 ()
# Shape of filter:1233 ()
# Shape of filter:1234 ()
# Shape of filter:1235 ()
# Shape of filter:1236 ()
# Shape of filter:1237 ()
# Shape of filter:1238 ()
# Shape of filter:1239 ()
# Shape of filter:1240 ()
# Shape of filter:1241 ()
# Shape of filter:1242 ()
# Shape of filter:1243 ()
# Shape of filter:1244 ()
# Shape of filter:1245 ()
# Shape of filter:1246 ()
# Shape of filter:1247 ()
# Shape of filter:1248 ()
# Shape of filter:1249 ()
# Shape of filter:1250 ()
# Shape of filter:1251 ()
# Shape of filter:1252 ()
# Shape of filter:1253 ()
# Shape of filter:1254 ()
# Shape of filter:1255 ()
# Shape of filter:1256 ()
# Shape of filter:1257 ()
# Shape of filter:1258 ()
# Shape of filter:1259 ()
# Shape of filter:1260 ()
# Shape of filter:1261 ()
# Shape of filter:1262 ()
# Shape of filter:1263 ()
# Shape of filter:1264 ()
# Shape of filter:1265 ()
# Shape of filter:1266 ()
# Shape of filter:1267 ()
# Shape of filter:1268 ()
# Shape of filter:1269 ()
# Shape of filter:1270 ()
# Shape of filter:1271 ()
# Shape of filter:1272 ()
# Shape of filter:1273 ()
# Shape of filter:1274 ()
# Shape of filter:1275 ()
# Shape of filter:1276 ()
# Shape of filter:1277 ()
# Shape of filter:1278 ()
# Shape of filter:1279 ()
# Shape of filter:1280 ()
# Shape of filter:1281 ()
# Shape of filter:1282 ()
# Shape of filter:1283 ()
# Shape of filter:1284 ()
# Shape of filter:1285 ()
# Shape of filter:1286 ()
# Shape of filter:1287 ()
# Shape of filter:1288 ()
# Shape of filter:1289 ()
# Shape of filter:1290 ()
# Shape of filter:1291 ()
# Shape of filter:1292 ()
# Shape of filter:1293 ()
# Shape of filter:1294 ()
# Shape of filter:1295 ()
# Shape of filter:1296 ()
# Shape of filter:1297 ()
# Shape of filter:1298 ()
# Shape of filter:1299 ()
# Shape of filter:1300 ()
# Shape of filter:1301 ()
# Shape of filter:1302 ()
# Shape of filter:1303 ()
# Shape of filter:1304 ()
# Shape of filter:1305 ()
# Shape of filter:1306 ()
# Shape of filter:1307 ()
# Shape of filter:1308 ()
# Shape of filter:1309 ()
# Shape of filter:1310 ()
# Shape of filter:1311 ()
# Shape of filter:1312 ()
# Shape of filter:1313 ()
# Shape of filter:1314 ()
# Shape of filter:1315 ()
# Shape of filter:1316 ()
# Shape of filter:1317 ()
# Shape of filter:1318 ()
# Shape of filter:1319 ()
# Shape of filter:1320 ()
# Shape of filter:1321 ()
# Shape of filter:1322 ()
# Shape of filter:1323 ()
# Shape of filter:1324 ()
# Shape of filter:1325 ()
# Shape of filter:1326 ()
# Shape of filter:1327 ()
# Shape of filter:1328 ()
# Shape of filter:1329 ()
# Shape of filter:1330 ()
# Shape of filter:1331 ()
# Shape of filter:1332 ()
# Shape of filter:1333 ()
# Shape of filter:1334 ()
# Shape of filter:1335 ()
# Shape of filter:1336 ()
# Shape of filter:1337 ()
# Shape of filter:1338 ()
# Shape of filter:1339 ()
# Shape of filter:1340 ()
# Shape of filter:1341 ()
# Shape of filter:1342 ()
# Shape of filter:1343 ()
# Shape of filter:1344 ()
# Shape of filter:1345 ()
# Shape of filter:1346 ()
# Shape of filter:1347 ()
# Shape of filter:1348 ()
# Shape of filter:1349 ()
# Shape of filter:1350 ()
# Shape of filter:1351 ()
# Shape of filter:1352 ()
# Shape of filter:1353 ()
# Shape of filter:1354 ()
# Shape of filter:1355 ()
# Shape of filter:1356 ()
# Shape of filter:1357 ()
# Shape of filter:1358 ()
# Shape of filter:1359 ()
# Shape of filter:1360 ()
# Shape of filter:1361 ()
# Shape of filter:1362 ()
# Shape of filter:1363 ()
# Shape of filter:1364 ()
# Shape of filter:1365 ()
# Shape of filter:1366 ()
# Shape of filter:1367 ()
# Shape of filter:1368 ()
# Shape of filter:1369 ()
# Shape of filter:1370 ()
# Shape of filter:1371 ()
# Shape of filter:1372 ()
# Shape of filter:1373 ()
# Shape of filter:1374 ()
# Shape of filter:1375 ()
# Shape of filter:1376 ()
# Shape of filter:1377 ()
# Shape of filter:1378 ()
# Shape of filter:1379 ()
# Shape of filter:1380 ()
# Shape of filter:1381 ()
# Shape of filter:1382 ()
# Shape of filter:1383 ()
# Shape of filter:1384 ()
# Shape of filter:1385 ()
# Shape of filter:1386 ()
# Shape of filter:1387 ()
# Shape of filter:1388 ()
# Shape of filter:1389 ()
# Shape of filter:1390 ()
# Shape of filter:1391 ()
# Shape of filter:1392 ()
# Shape of filter:1393 ()
# Shape of filter:1394 ()
# Shape of filter:1395 ()
# Shape of filter:1396 ()
# Shape of filter:1397 ()
# Shape of filter:1398 ()
# Shape of filter:1399 ()
# Shape of filter:1400 ()
# Shape of filter:1401 ()
# Shape of filter:1402 ()
# Shape of filter:1403 ()
# Shape of filter:1404 ()
# Shape of filter:1405 ()
# Shape of filter:1406 ()
# Shape of filter:1407 ()
# Shape of filter:1408 ()
# Shape of filter:1409 ()
# Shape of filter:1410 ()
# Shape of filter:1411 ()
# Shape of filter:1412 ()
# Shape of filter:1413 ()
# Shape of filter:1414 ()
# Shape of filter:1415 ()
# Shape of filter:1416 ()
# Shape of filter:1417 ()
# Shape of filter:1418 ()
# Shape of filter:1419 ()
# Shape of filter:1420 ()
# Shape of filter:1421 ()
# Shape of filter:1422 ()
# Shape of filter:1423 ()
# Shape of filter:1424 ()
# Shape of filter:1425 ()
# Shape of filter:1426 ()
# Shape of filter:1427 ()
# Shape of filter:1428 ()
# Shape of filter:1429 ()
# Shape of filter:1430 ()
# Shape of filter:1431 ()
# Shape of filter:1432 ()
# Shape of filter:1433 ()
# Shape of filter:1434 ()
# Shape of filter:1435 ()
# Shape of filter:1436 ()
# Shape of filter:1437 ()
# Shape of filter:1438 ()
# Shape of filter:1439 ()
# Shape of filter:1440 ()
# Shape of filter:1441 ()
# Shape of filter:1442 ()
# Shape of filter:1443 ()
# Shape of filter:1444 ()
# Shape of filter:1445 ()
# Shape of filter:1446 ()
# Shape of filter:1447 ()
# Shape of filter:1448 ()
# Shape of filter:1449 ()
# Shape of filter:1450 ()
# Shape of filter:1451 ()
# Shape of filter:1452 ()
# Shape of filter:1453 ()
# Shape of filter:1454 ()
# Shape of filter:1455 ()
# Shape of filter:1456 ()
# Shape of filter:1457 ()
# Shape of filter:1458 ()
# Shape of filter:1459 ()
# Shape of filter:1460 ()
# Shape of filter:1461 ()
# Shape of filter:1462 ()
# Shape of filter:1463 ()
# Shape of filter:1464 ()
# Shape of filter:1465 ()
# Shape of filter:1466 ()
# Shape of filter:1467 ()
# Shape of filter:1468 ()
# Shape of filter:1469 ()
# Shape of filter:1470 ()
# Shape of filter:1471 ()
# Shape of filter:1472 ()
# Shape of filter:1473 ()
# Shape of filter:1474 ()
# Shape of filter:1475 ()
# Shape of filter:1476 ()
# Shape of filter:1477 ()
# Shape of filter:1478 ()
# Shape of filter:1479 ()
# Shape of filter:1480 ()
# Shape of filter:1481 ()
# Shape of filter:1482 ()
# Shape of filter:1483 ()
# Shape of filter:1484 ()
# Shape of filter:1485 ()
# Shape of filter:1486 ()
# Shape of filter:1487 ()
# Shape of filter:1488 ()
# Shape of filter:1489 ()
# Shape of filter:1490 ()
# Shape of filter:1491 ()
# Shape of filter:1492 ()
# Shape of filter:1493 ()
# Shape of filter:1494 ()
# Shape of filter:1495 ()
# Shape of filter:1496 ()
# Shape of filter:1497 ()
# Shape of filter:1498 ()
# Shape of filter:1499 ()
# Shape of filter:1500 ()
# Shape of filter:1501 ()
# Shape of filter:1502 ()
# Shape of filter:1503 ()
# Shape of filter:1504 ()
# Shape of filter:1505 ()
# Shape of filter:1506 ()
# Shape of filter:1507 ()
# Shape of filter:1508 ()
# Shape of filter:1509 ()
# Shape of filter:1510 ()
# Shape of filter:1511 ()
# Shape of filter:1512 ()
# Shape of filter:1513 ()
# Shape of filter:1514 ()
# Shape of filter:1515 ()
# Shape of filter:1516 ()
# Shape of filter:1517 ()
# Shape of filter:1518 ()
# Shape of filter:1519 ()
# Shape of filter:1520 ()
# Shape of filter:1521 ()
# Shape of filter:1522 ()
# Shape of filter:1523 ()
# Shape of filter:1524 ()
# Shape of filter:1525 ()
# Shape of filter:1526 ()
# Shape of filter:1527 ()
# Shape of filter:1528 ()
# Shape of filter:1529 ()
# Shape of filter:1530 ()
# Shape of filter:1531 ()
# Shape of filter:1532 ()
# Shape of filter:1533 ()
# Shape of filter:1534 ()
# Shape of filter:1535 ()
# Shape of filter:1536 ()
# Shape of filter:1537 ()
# Shape of filter:1538 ()
# Shape of filter:1539 ()
# Shape of filter:1540 ()
# Shape of filter:1541 ()
# Shape of filter:1542 ()
# Shape of filter:1543 ()
# Shape of filter:1544 ()
# Shape of filter:1545 ()
# Shape of filter:1546 ()
# Shape of filter:1547 ()
# Shape of filter:1548 ()
# Shape of filter:1549 ()
# Shape of filter:1550 ()
# Shape of filter:1551 ()
# Shape of filter:1552 ()
# Shape of filter:1553 ()
# Shape of filter:1554 ()
# Shape of filter:1555 ()
# Shape of filter:1556 ()
# Shape of filter:1557 ()
# Shape of filter:1558 ()
# Shape of filter:1559 ()
# Shape of filter:1560 ()
# Shape of filter:1561 ()
# Shape of filter:1562 ()
# Shape of filter:1563 ()
# Shape of filter:1564 ()
# Shape of filter:1565 ()
# Shape of filter:1566 ()
# Shape of filter:1567 ()
# Shape of filter:1568 ()
# Shape of filter:1569 ()
# Shape of filter:1570 ()
# Shape of filter:1571 ()
# Shape of filter:1572 ()
# Shape of filter:1573 ()
# Shape of filter:1574 ()
# Shape of filter:1575 ()
# Shape of filter:1576 ()
# Shape of filter:1577 ()
# Shape of filter:1578 ()
# Shape of filter:1579 ()
# Shape of filter:1580 ()
# Shape of filter:1581 ()
# Shape of filter:1582 ()
# Shape of filter:1583 ()
# Shape of filter:1584 ()
# Shape of filter:1585 ()
# Shape of filter:1586 ()
# Shape of filter:1587 ()
# Shape of filter:1588 ()
# Shape of filter:1589 ()
# Shape of filter:1590 ()
# Shape of filter:1591 ()
# Shape of filter:1592 ()
# Shape of filter:1593 ()
# Shape of filter:1594 ()
# Shape of filter:1595 ()
# Shape of filter:1596 ()
# Shape of filter:1597 ()
# Shape of filter:1598 ()
# Shape of filter:1599 ()
# Shape of filter:1600 ()
# Shape of filter:1601 ()
# Shape of filter:1602 ()
# Shape of filter:1603 ()
# Shape of filter:1604 ()
# Shape of filter:1605 ()
# Shape of filter:1606 ()
# Shape of filter:1607 ()
# Shape of filter:1608 ()
# Shape of filter:1609 ()
# Shape of filter:1610 ()
# Shape of filter:1611 ()
# Shape of filter:1612 ()
# Shape of filter:1613 ()
# Shape of filter:1614 ()
# Shape of filter:1615 ()
# Shape of filter:1616 ()
# Shape of filter:1617 ()
# Shape of filter:1618 ()
# Shape of filter:1619 ()
# Shape of filter:1620 ()
# Shape of filter:1621 ()
# Shape of filter:1622 ()
# Shape of filter:1623 ()
# Shape of filter:1624 ()
# Shape of filter:1625 ()
# Shape of filter:1626 ()
# Shape of filter:1627 ()
# Shape of filter:1628 ()
# Shape of filter:1629 ()
# Shape of filter:1630 ()
# Shape of filter:1631 ()
# Shape of filter:1632 ()
# Shape of filter:1633 ()
# Shape of filter:1634 ()
# Shape of filter:1635 ()
# Shape of filter:1636 ()
# Shape of filter:1637 ()
# Shape of filter:1638 ()
# Shape of filter:1639 ()
# Shape of filter:1640 ()
# Shape of filter:1641 ()
# Shape of filter:1642 ()
# Shape of filter:1643 ()
# Shape of filter:1644 ()
# Shape of filter:1645 ()
# Shape of filter:1646 ()
# Shape of filter:1647 ()
# Shape of filter:1648 ()
# Shape of filter:1649 ()
# Shape of filter:1650 ()
# Shape of filter:1651 ()
# Shape of filter:1652 ()
# Shape of filter:1653 ()
# Shape of filter:1654 ()
# Shape of filter:1655 ()
# Shape of filter:1656 ()
# Shape of filter:1657 ()
# Shape of filter:1658 ()
# Shape of filter:1659 ()
# Shape of filter:1660 ()
# Shape of filter:1661 ()
# Shape of filter:1662 ()
# Shape of filter:1663 ()
# Shape of filter:1664 ()
# Shape of filter:1665 ()
# Shape of filter:1666 ()
# Shape of filter:1667 ()
# Shape of filter:1668 ()
# Shape of filter:1669 ()
# Shape of filter:1670 ()
# Shape of filter:1671 ()
# Shape of filter:1672 ()
# Shape of filter:1673 ()
# Shape of filter:1674 ()
# Shape of filter:1675 ()
# Shape of filter:1676 ()
# Shape of filter:1677 ()
# Shape of filter:1678 ()
# Shape of filter:1679 ()
# Shape of filter:1680 ()
# Shape of filter:1681 ()
# Shape of filter:1682 ()
# Shape of filter:1683 ()
# Shape of filter:1684 ()
# Shape of filter:1685 ()
# Shape of filter:1686 ()
# Shape of filter:1687 ()
# Shape of filter:1688 ()
# Shape of filter:1689 ()
# Shape of filter:1690 ()
# Shape of filter:1691 ()
# Shape of filter:1692 ()
# Shape of filter:1693 ()
# Shape of filter:1694 ()
# Shape of filter:1695 ()
# Shape of filter:1696 ()
# Shape of filter:1697 ()
# Shape of filter:1698 ()
# Shape of filter:1699 ()
# Shape of filter:1700 ()
# Shape of filter:1701 ()
# Shape of filter:1702 ()
# Shape of filter:1703 ()
# Shape of filter:1704 ()
# Shape of filter:1705 ()
# Shape of filter:1706 ()
# Shape of filter:1707 ()
# Shape of filter:1708 ()
# Shape of filter:1709 ()
# Shape of filter:1710 ()
# Shape of filter:1711 ()
# Shape of filter:1712 ()
# Shape of filter:1713 ()
# Shape of filter:1714 ()
# Shape of filter:1715 ()
# Shape of filter:1716 ()
# Shape of filter:1717 ()
# Shape of filter:1718 ()
# Shape of filter:1719 ()
# Shape of filter:1720 ()
# Shape of filter:1721 ()
# Shape of filter:1722 ()
# Shape of filter:1723 ()
# Shape of filter:1724 ()
# Shape of filter:1725 ()
# Shape of filter:1726 ()
# Shape of filter:1727 ()
# Shape of filter:1728 ()
# Shape of filter:1729 ()
# Shape of filter:1730 ()
# Shape of filter:1731 ()
# Shape of filter:1732 ()
# Shape of filter:1733 ()
# Shape of filter:1734 ()
# Shape of filter:1735 ()
# Shape of filter:1736 ()
# Shape of filter:1737 ()
# Shape of filter:1738 ()
# Shape of filter:1739 ()
# Shape of filter:1740 ()
# Shape of filter:1741 ()
# Shape of filter:1742 ()
# Shape of filter:1743 ()
# Shape of filter:1744 ()
# Shape of filter:1745 ()
# Shape of filter:1746 ()
# Shape of filter:1747 ()
# Shape of filter:1748 ()
# Shape of filter:1749 ()
# Shape of filter:1750 ()
# Shape of filter:1751 ()
# Shape of filter:1752 ()
# Shape of filter:1753 ()
# Shape of filter:1754 ()
# Shape of filter:1755 ()
# Shape of filter:1756 ()
# Shape of filter:1757 ()
# Shape of filter:1758 ()
# Shape of filter:1759 ()
# Shape of filter:1760 ()
# Shape of filter:1761 ()
# Shape of filter:1762 ()
# Shape of filter:1763 ()
# Shape of filter:1764 ()
# Shape of filter:1765 ()
# Shape of filter:1766 ()
# Shape of filter:1767 ()
# Shape of filter:1768 ()
# Shape of filter:1769 ()
# Shape of filter:1770 ()
# Shape of filter:1771 ()
# Shape of filter:1772 ()
# Shape of filter:1773 ()
# Shape of filter:1774 ()
# Shape of filter:1775 ()
# Shape of filter:1776 ()
# Shape of filter:1777 ()
# Shape of filter:1778 ()
# Shape of filter:1779 ()
# Shape of filter:1780 ()
# Shape of filter:1781 ()
# Shape of filter:1782 ()
# Shape of filter:1783 ()
# Shape of filter:1784 ()
# Shape of filter:1785 ()
# Shape of filter:1786 ()
# Shape of filter:1787 ()
# Shape of filter:1788 ()
# Shape of filter:1789 ()
# Shape of filter:1790 ()
# Shape of filter:1791 ()
# Shape of filter:1792 ()
# Shape of filter:1793 ()
# Shape of filter:1794 ()
# Shape of filter:1795 ()
# Shape of filter:1796 ()
# Shape of filter:1797 ()
# Shape of filter:1798 ()
# Shape of filter:1799 ()
# Shape of filter:1800 ()
# Shape of filter:1801 ()
# Shape of filter:1802 ()
# Shape of filter:1803 ()
# Shape of filter:1804 ()
# Shape of filter:1805 ()
# Shape of filter:1806 ()
# Shape of filter:1807 ()
# Shape of filter:1808 ()
# Shape of filter:1809 ()
# Shape of filter:1810 ()
# Shape of filter:1811 ()
# Shape of filter:1812 ()
# Shape of filter:1813 ()
# Shape of filter:1814 ()
# Shape of filter:1815 ()
# Shape of filter:1816 ()
# Shape of filter:1817 ()
# Shape of filter:1818 ()
# Shape of filter:1819 ()
# Shape of filter:1820 ()
# Shape of filter:1821 ()
# Shape of filter:1822 ()
# Shape of filter:1823 ()
# Shape of filter:1824 ()
# Shape of filter:1825 ()
# Shape of filter:1826 ()
# Shape of filter:1827 ()
# Shape of filter:1828 ()
# Shape of filter:1829 ()
# Shape of filter:1830 ()
# Shape of filter:1831 ()
# Shape of filter:1832 ()
# Shape of filter:1833 ()
# Shape of filter:1834 ()
# Shape of filter:1835 ()
# Shape of filter:1836 ()
# Shape of filter:1837 ()
# Shape of filter:1838 ()
# Shape of filter:1839 ()
# Shape of filter:1840 ()
# Shape of filter:1841 ()
# Shape of filter:1842 ()
# Shape of filter:1843 ()
# Shape of filter:1844 ()
# Shape of filter:1845 ()
# Shape of filter:1846 ()
# Shape of filter:1847 ()
# Shape of filter:1848 ()
# Shape of filter:1849 ()
# Shape of filter:1850 ()
# Shape of filter:1851 ()
# Shape of filter:1852 ()
# Shape of filter:1853 ()
# Shape of filter:1854 ()
# Shape of filter:1855 ()
# Shape of filter:1856 ()
# Shape of filter:1857 ()
# Shape of filter:1858 ()
# Shape of filter:1859 ()
# Shape of filter:1860 ()
# Shape of filter:1861 ()
# Shape of filter:1862 ()
# Shape of filter:1863 ()
# Shape of filter:1864 ()
# Shape of filter:1865 ()
# Shape of filter:1866 ()
# Shape of filter:1867 ()
# Shape of filter:1868 ()
# Shape of filter:1869 ()
# Shape of filter:1870 ()
# Shape of filter:1871 ()
# Shape of filter:1872 ()
# Shape of filter:1873 ()
# Shape of filter:1874 ()
# Shape of filter:1875 ()
# Shape of filter:1876 ()
# Shape of filter:1877 ()
# Shape of filter:1878 ()
# Shape of filter:1879 ()
# Shape of filter:1880 ()
# Shape of filter:1881 ()
# Shape of filter:1882 ()
# Shape of filter:1883 ()
# Shape of filter:1884 ()
# Shape of filter:1885 ()
# Shape of filter:1886 ()
# Shape of filter:1887 ()
# Shape of filter:1888 ()
# Shape of filter:1889 ()
# Shape of filter:1890 ()
# Shape of filter:1891 ()
# Shape of filter:1892 ()
# Shape of filter:1893 ()
# Shape of filter:1894 ()
# Shape of filter:1895 ()
# Shape of filter:1896 ()
# Shape of filter:1897 ()
# Shape of filter:1898 ()
# Shape of filter:1899 ()
# Shape of filter:1900 ()
# Shape of filter:1901 ()
# Shape of filter:1902 ()
# Shape of filter:1903 ()
# Shape of filter:1904 ()
# Shape of filter:1905 ()
# Shape of filter:1906 ()
# Shape of filter:1907 ()
# Shape of filter:1908 ()
# Shape of filter:1909 ()
# Shape of filter:1910 ()
# Shape of filter:1911 ()
# Shape of filter:1912 ()
# Shape of filter:1913 ()
# Shape of filter:1914 ()
# Shape of filter:1915 ()
# Shape of filter:1916 ()
# Shape of filter:1917 ()
# Shape of filter:1918 ()
# Shape of filter:1919 ()
# Shape of filter:1920 ()
# Shape of filter:1921 ()
# Shape of filter:1922 ()
# Shape of filter:1923 ()
# Shape of filter:1924 ()
# Shape of filter:1925 ()
# Shape of filter:1926 ()
# Shape of filter:1927 ()
# Shape of filter:1928 ()
# Shape of filter:1929 ()
# Shape of filter:1930 ()
# Shape of filter:1931 ()
# Shape of filter:1932 ()
# Shape of filter:1933 ()
# Shape of filter:1934 ()
# Shape of filter:1935 ()
# Shape of filter:1936 ()
# Shape of filter:1937 ()
# Shape of filter:1938 ()
# Shape of filter:1939 ()
# Shape of filter:1940 ()
# Shape of filter:1941 ()
# Shape of filter:1942 ()
# Shape of filter:1943 ()
# Shape of filter:1944 ()
# Shape of filter:1945 ()
# Shape of filter:1946 ()
# Shape of filter:1947 ()
# Shape of filter:1948 ()
# Shape of filter:1949 ()
# Shape of filter:1950 ()
# Shape of filter:1951 ()
# Shape of filter:1952 ()
# Shape of filter:1953 ()
# Shape of filter:1954 ()
# Shape of filter:1955 ()
# Shape of filter:1956 ()
# Shape of filter:1957 ()
# Shape of filter:1958 ()
# Shape of filter:1959 ()
# Shape of filter:1960 ()
# Shape of filter:1961 ()
# Shape of filter:1962 ()
# Shape of filter:1963 ()
# Shape of filter:1964 ()
# Shape of filter:1965 ()
# Shape of filter:1966 ()
# Shape of filter:1967 ()
# Shape of filter:1968 ()
# Shape of filter:1969 ()
# Shape of filter:1970 ()
# Shape of filter:1971 ()
# Shape of filter:1972 ()
# Shape of filter:1973 ()
# Shape of filter:1974 ()
# Shape of filter:1975 ()
# Shape of filter:1976 ()
# Shape of filter:1977 ()
# Shape of filter:1978 ()
# Shape of filter:1979 ()
# Shape of filter:1980 ()
# Shape of filter:1981 ()
# Shape of filter:1982 ()
# Shape of filter:1983 ()
# Shape of filter:1984 ()
# Shape of filter:1985 ()
# Shape of filter:1986 ()
# Shape of filter:1987 ()
# Shape of filter:1988 ()
# Shape of filter:1989 ()
# Shape of filter:1990 ()
# Shape of filter:1991 ()
# Shape of filter:1992 ()
# Shape of filter:1993 ()
# Shape of filter:1994 ()
# Shape of filter:1995 ()
# Shape of filter:1996 ()
# Shape of filter:1997 ()
# Shape of filter:1998 ()
# Shape of filter:1999 ()
# Shape of filter:2000 ()
# Shape of filter:2001 ()
# Shape of filter:2002 ()
# Shape of filter:2003 ()
# Shape of filter:2004 ()
# Shape of filter:2005 ()
# Shape of filter:2006 ()
# Shape of filter:2007 ()
# Shape of filter:2008 ()
# Shape of filter:2009 ()
# Shape of filter:2010 ()
# Shape of filter:2011 ()
# Shape of filter:2012 ()
# Shape of filter:2013 ()
# Shape of filter:2014 ()
# Shape of filter:2015 ()
# Shape of filter:2016 ()
# Shape of filter:2017 ()
# Shape of filter:2018 ()
# Shape of filter:2019 ()
# Shape of filter:2020 ()
# Shape of filter:2021 ()
# Shape of filter:2022 ()
# Shape of filter:2023 ()
# Shape of filter:2024 ()
# Shape of filter:2025 ()
# Shape of filter:2026 ()
# Shape of filter:2027 ()
# Shape of filter:2028 ()
# Shape of filter:2029 ()
# Shape of filter:2030 ()
# Shape of filter:2031 ()
# Shape of filter:2032 ()
# Shape of filter:2033 ()
# Shape of filter:2034 ()
# Shape of filter:2035 ()
# Shape of filter:2036 ()
# Shape of filter:2037 ()
# Shape of filter:2038 ()
# Shape of filter:2039 ()
# Shape of filter:2040 ()
# Shape of filter:2041 ()
# Shape of filter:2042 ()
# Shape of filter:2043 ()
# Shape of filter:2044 ()
# Shape of filter:2045 ()
# Shape of filter:2046 ()
# Shape of filter:2047 ()
